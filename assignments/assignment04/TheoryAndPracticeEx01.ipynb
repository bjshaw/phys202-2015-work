# %% [markdown]
# # Theory and Practice of Visualization Exercise 1

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *positive* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [Vox](http://www.vox.com/)
# * [Upshot](http://www.nytimes.com/upshot/)
# * [538](http://fivethirtyeight.com/)
# * [BuzzFeed](http://www.buzzfeed.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
Image(filename='jobsadded.png')

# %% [markdown]
# Describe in detail the ways in which the visualization exhibits graphical *integrity* and *excellence*:

# %% [markdown]
# First of all, the title explains the purpose of the graph, and also explains what both axes represent.  This reduces the necessity of explicitly labeling the axes, which makes the graph less cluttered.  Only one of the numbers on each axis is written in full, to give context and meaningful unit which the rest of the numbers follow.  This again reduces the clutter on the graph.  The two lines on the graph are color coded, which makes them easily readable and discernable.  The lines are also labeled directly on the graph, which takes up less space than a legend and increases the integrity.  The grid helps to compare any two points on the graph, and is unobstrusive.  Overall, this graph is simple yet elegant.  It achieves its purpose without unneeded reduncies which would otherwise clutter the graph.
